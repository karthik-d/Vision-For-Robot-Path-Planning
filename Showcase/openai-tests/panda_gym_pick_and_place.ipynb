# %%
# %pip install panda-gym
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting panda-gym
#   Downloading panda_gym-3.0.4-py3-none-any.whl (23 kB)
# Collecting gymnasium~=0.26
#   Downloading gymnasium-0.27.1-py3-none-any.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 KB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from panda-gym) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from panda-gym) (1.7.3)
# Collecting pybullet
#   Downloading pybullet-3.2.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (91.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 MB 10.1 MB/s eta 0:00:00
# Collecting gymnasium-notices>=0.0.1
#   Downloading gymnasium_notices-0.0.1-py3-none-any.whl (2.8 kB)
# Collecting jax-jumpy>=0.2.0
#   Downloading jax_jumpy-0.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium~=0.26->panda-gym) (4.4.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium~=0.26->panda-gym) (6.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gymnasium~=0.26->panda-gym) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.8.0->gymnasium~=0.26->panda-gym) (3.12.0)
# Installing collected packages: pybullet, gymnasium-notices, jax-jumpy, gymnasium, panda-gym
# Successfully installed gymnasium-0.27.1 gymnasium-notices-0.0.1 jax-jumpy-0.2.0 panda-gym-3.0.4 pybullet-3.2.5

# %%
import gymnasium as gym
import panda_gym

env = gym.make("PandaPickAndPlace-v3", render_mode="rgb_array")
observation, info = env.reset()

images = [env.render()]
for _ in range(200):
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    images.append(env.render())

    if terminated or truncated:
        observation, info = env.reset()
        images.append(env.render())

env.close()

# %%
# %pip install numpngw
from numpngw import write_apng

write_apng("anim.png", images, delay=40)  # real-time rendering = 40 ms between frames
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpngw
#   Downloading numpngw-0.1.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from numpngw) (1.21.6)
# Installing collected packages: numpngw
# Successfully installed numpngw-0.1.2

# %%
from IPython.display import Image

Image(filename="anim.png")
